# %%
import matplotlib.pyplot as plt
#Défini les données
import numpy as np
data = np.loadtxt("source2_lowenergy.txt",unpack=True,dtype=float)
x = data[0]
y = data[2]
plt.figure()
plt.xlabel("axe des X")
plt.ylabel("Axe des Y")
plt.errorbar(x,y,fmt='.')

##AJUSTEMENT AVEC UN POL D ORDRE 2
z = np.polyfit(x, y, 2)
xx = np.linspace(np.min(x),np.max(x))
p = np.poly1d(z)
print(x[np.argmax(p(x))])
print("Source 2 : Energy maximum : ",(np.power(10,x[np.argmax(p(x))])*1e12) , " eV")

plt.plot(xx,p(xx),label='model')

data = numpy.loadtxt("source2_fermi.txt",unpack=True,dtype=float)
x = data[0]
y = data[2]
plt.errorbar(x,y,fmt='.')
plt.show() #permet de tracer
# Out:
# -10.684742
# Source 2 : Energy maximum :  20.666074944330912  eV

# %%
print("ajouter les points obtenus lors du TP")
print("ajuster ces données avec celle de Fermi")
